# %%
# !git clone https://github.com/tomsamwel/whisper-diarization.git
# Out:
# Cloning into 'whisper-diarization'...
# remote: Enumerating objects: 252, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 252 (delta 130), reused 116 (delta 108), pack-reused 92
# Receiving objects: 100% (252/252), 80.97 KiB | 1.80 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %%
# !sudo apt update && sudo apt install ffmpeg
# !pip install cython
# !pip install -r /kaggle/working/whisper-diarization/requirements.txt
# Out:
# ...
#   Cloning https://github.com/m-bain/whisperX.git (to revision a5dca2cc65b1a37f32a347e574b2c56af3a7434a) to /tmp/pip-req-build-4n519a_p
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperX.git /tmp/pip-req-build-4n519a_p
#   Running command git rev-parse -q --verify 'sha^a5dca2cc65b1a37f32a347e574b2c56af3a7434a'
#   Running command git fetch -q https://github.com/m-bain/whisperX.git a5dca2cc65b1a37f32a347e574b2c56af3a7434a
#   Running command git checkout -q a5dca2cc65b1a37f32a347e574b2c56af3a7434a
#   Resolved https://github.com/m-bain/whisperX.git to commit a5dca2cc65b1a37f32a347e574b2c56af3a7434a
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/demucs to /tmp/pip-install-l23p637l/demucs_62b53553d45b44d197de35cb41abfc7b
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/demucs /tmp/pip-install-l23p637l/demucs_62b53553d45b44d197de35cb41abfc7b
# ...

# %%
import shutil
shutil.copytree('/kaggle/input/gespreksopnames', '/kaggle/working/gespreksopnames')

# %%
input_file = ".mp3"
whisper_model = "large-v3"
language = "nl"

# !python /kaggle/working/whisper-diarization/diarize.py -a "{input_file}" --whisper-model "{whisper_model}" --language "{language}"
# Out:
# 2024-02-20 14:17:10.821862: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-20 14:17:10.821959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-20 14:17:10.986311: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
